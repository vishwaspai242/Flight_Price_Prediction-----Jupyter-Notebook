# %% [markdown]
# # Flight Price Prediction

# %% [markdown]
# ### Problem Statement:

# %% [markdown]
# Flight ticket prices can be something hard to guess, today we might see a price, check out the price of the same flight tomorrow, it will be a different story. We might have often heard travellers saying that flight ticket prices are so unpredictable. Here you will be provided with prices of flight tickets for various airlines between the months of March and June of 2019 and between various cities.

# %% [markdown]
# Size of training set: 10683 records
#
# Size of test set: 2671 records

# %% [markdown]
# FEATURES:
#
# Airline: The name of the airline.
#
# Date_of_Journey: The date of the journey
#
# Source: The source from which the service begins.
#
# Destination: The destination where the service ends.
#
# Route: The route taken by the flight to reach the destination.
#
# Dep_Time: The time when the journey starts from the source.
#
# Arrival_Time: Time of arrival at the destination.
#
# Duration: Total duration of the flight.
#
# Total_Stops: Total stops between the source and destination.
#
# Additional_Info: Additional information about the flight
#
# Price: The price of the ticket

# %% [markdown]
# building a machine learning model to predict the price of the flight ticket.

# %%
# Importing required Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

from scipy.stats import zscore
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn import metrics

# %% [markdown]
# # Importing the training dataset

# %%
df_train = pd.read_excel('Flight_Price_Prediction_Data_Train.xlsx')

# %% [markdown]
# I downloaded the zip file from the source on my local computer then extracted it's contents. I moved the extracted data to my working directory on the Jupyter Notebook and renamed them to convienient names and then imported the excel spread sheet using pandas.

# %%
df_train
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# 2      DEL → LKO → BOM → COK    09:25  04:25 10 Jun      19h     2 stops
# 3            CCU → NAG → BLR    18:05         23:30   5h 25m      1 stop
# 4            BLR → NAG → DEL    16:50         21:35   4h 45m      1 stop
# ...                      ...      ...           ...      ...         ...
# 10678              CCU → BLR    19:55         22:25   2h 30m    non-stop
# 10679              CCU → BLR    20:45         23:20   2h 35m    non-stop
# 10680              BLR → DEL    08:20         11:20       3h    non-stop
# 10681              BLR → DEL    11:30         14:10   2h 40m    non-stop
# 10682  DEL → GOI → BOM → COK    10:55         19:15   8h 20m     2 stops
#
#       Additional_Info  Price
# 0             No info   3897
# 1             No info   7662
# 2             No info  13882
# 3             No info   6218
# 4             No info  13302
# ...               ...    ...
# 10678         No info   4107
# 10679         No info   4145
# 10680         No info   7229
# 10681         No info  12648
# 10682         No info  11753
#
# [10683 rows x 11 columns]

# %% [markdown]
# ### Training Dataset:

# %% [markdown]
# This train dataset contains the data about the price of flights of different airlines. For predicting the price based on the actual data we will take help of the other features provided in the dataset.

# %% [markdown]
# The target variable here is the price which is a continuous data. Based on this we will build a predicting model for continuous data that is a regression model.

# %% [markdown]
# # Exploratory Data Analysis(EDA)

# %%
df_train.head(3)
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882

# %%
df_train.tail(3)
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time Arrival_Time Duration Total_Stops  \
# 10680              BLR → DEL    08:20        11:20       3h    non-stop
# 10681              BLR → DEL    11:30        14:10   2h 40m    non-stop
# 10682  DEL → GOI → BOM → COK    10:55        19:15   8h 20m     2 stops
#
#       Additional_Info  Price
# 10680         No info   7229
# 10681         No info  12648
# 10682         No info  11753

# %%
df_train.sample(3)
# Out:
#                  Airline Date_of_Journey   Source Destination  \
# 98           Jet Airways      18/06/2019   Mumbai   Hyderabad
# 1248         Jet Airways      24/05/2019  Kolkata    Banglore
# 10525  Multiple carriers      24/06/2019    Delhi      Cochin
#
#                  Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 98           BOM → HYD    07:05         08:30   1h 25m    non-stop
# 1248   CCU → BOM → BLR    14:05  04:40 25 May  14h 35m      1 stop
# 10525  DEL → BOM → COK    08:00         21:00      13h      1 stop
#
#                    Additional_Info  Price
# 98                         No info   8040
# 1248   In-flight meal not included   8586
# 10525                      No info  13797

# %%
df_train.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Dep_Time', 'Arrival_Time', 'Duration', 'Total_Stops',
#        'Additional_Info', 'Price'],
#       dtype='object')

# %%
#Checking the size of the dataset
df_train.shape
# Out:
# (10683, 11)

# %% [markdown]
# We can see that we have 10683 rows and 11 columns out of which 10 are features and 1 is the target column

# %%
#Checking and overall overview of the datset
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Arrival_Time     10683 non-null  object
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10683 non-null  object
#  10  Price            10683 non-null  int64
# dtypes: int64(1), object(10)
# memory usage: 918.2+ KB

# %% [markdown]
# From this we can see that the dataset here shows apart from price all the columns have object type data with no null values, however we will check seperately and use the encoding and imputation techniques to make the date ready for modelling.

# %%
#checking the uniqueness of the dataset
df_train.nunique()
# Out:
# Airline              12
# Date_of_Journey      44
# Source                5
# Destination           6
# Route               128
# Dep_Time            222
# Arrival_Time       1343
# Duration            368
# Total_Stops           5
# Additional_Info      10
# Price              1870
# dtype: int64

# %%
#checking the null values
df_train.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              1
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        1
# Additional_Info    0
# Price              0
# dtype: int64

# %% [markdown]
# We can here see that the feature Route and Total_stops has 1 null values each.

# %%
sns.heatmap(df_train.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# We cannot see those 2 null values in the heat map since out of 10180 in each column there are only 1 null value each in 2 columns

# %%
df_train.dtypes
# Out:
# Airline            object
# Date_of_Journey    object
# Source             object
# Destination        object
# Route              object
# Dep_Time           object
# Arrival_Time       object
# Duration           object
# Total_Stops        object
# Additional_Info    object
# Price               int64
# dtype: object

# %% [markdown]
# We can see here that python is showing Date of journey, departure time and arrival time as object, hence we will have to convert it to timestamp for modelling

# %%
# Checking the value counts of each columns
for i in df_train.columns:
    print(df_train[i].value_counts())
    print('_____________________________________')
# Out:
# Jet Airways                          3849
# IndiGo                               2053
# Air India                            1752
# Multiple carriers                    1196
# SpiceJet                              818
# Vistara                               479
# Air Asia                              319
# GoAir                                 194
# Multiple carriers Premium economy      13
# Jet Airways Business                    6
# Vistara Premium economy                 3
# Trujet                                  1
# Name: Airline, dtype: int64
# _____________________________________
# 18/05/2019    504
# 6/06/2019     503
# 21/05/2019    497
# 9/06/2019     495
# 12/06/2019    493
# 9/05/2019     484
# 21/03/2019    423
# 15/05/2019    405
# 27/05/2019    382
# 27/06/2019    355
# 24/06/2019    351
# 1/06/2019     342
# 3/06/2019     333
# 15/06/2019    328
# 24/03/2019    323
# 6/03/2019     308
# 27/03/2019    299
# 24/05/2019    286
# 6/05/2019     282
# 1/05/2019     277
# 12/05/2019    259
# 1/04/2019     257
# 3/03/2019     218
# 9/03/2019     200
# 15/03/2019    162
# 18/03/2019    156
# 01/03/2019    152
# 12/03/2019    142
# 9/04/2019     125
# 3/04/2019     110
# 21/06/2019    109
# 18/06/2019    105
# 09/03/2019    102
# 6/04/2019     100
# 03/03/2019     97
# 06/03/2019     95
# 27/04/2019     94
# 24/04/2019     92
# 3/05/2019      90
# 15/04/2019     89
# 21/04/2019     82
# 18/04/2019     67
# 12/04/2019     63
# 1/03/2019      47
# Name: Date_of_Journey, dtype: int64
# _____________________________________
# Delhi       4537
# Kolkata     2871
# Banglore    2197
# Mumbai       697
# Chennai      381
# Name: Source, dtype: int64
# _____________________________________
# Cochin       4537
# Banglore     2871
# Delhi        1265
# New Delhi     932
# Hyderabad     697
# Kolkata       381
# Name: Destination, dtype: int64
# _____________________________________
# DEL → BOM → COK          2376
# BLR → DEL                1552
# CCU → BOM → BLR           979
# CCU → BLR                 724
# BOM → HYD                 621
#                          ...
# CCU → VTZ → BLR             1
# CCU → IXZ → MAA → BLR       1
# BOM → COK → MAA → HYD       1
# BOM → CCU → HYD             1
# BOM → BBI → HYD             1
# Name: Route, Length: 128, dtype: int64
# _____________________________________
# 18:55    233
# 17:00    227
# 07:05    205
# 10:00    203
# 07:10    202
#         ...
# 16:25      1
# 01:35      1
# 21:35      1
# 04:15      1
# 03:00      1
# Name: Dep_Time, Length: 222, dtype: int64
# _____________________________________
# 19:00           423
# 21:00           360
# 19:15           333
# 16:10           154
# 12:35           122
#                ...
# 00:25 02 Jun      1
# 08:55 13 Mar      1
# 11:05 19 May      1
# 12:30 22 May      1
# 21:20 13 Mar      1
# Name: Arrival_Time, Length: 1343, dtype: int64
# _____________________________________
# 2h 50m     550
# 1h 30m     386
# 2h 45m     337
# 2h 55m     337
# 2h 35m     329
#           ...
# 31h 30m      1
# 30h 25m      1
# 42h 5m       1
# 4h 10m       1
# 47h 40m      1
# Name: Duration, Length: 368, dtype: int64
# _____________________________________
# 1 stop      5625
# non-stop    3491
# 2 stops     1520
# 3 stops       45
# 4 stops        1
# Name: Total_Stops, dtype: int64
# _____________________________________
# No info                         8345
# In-flight meal not included     1982
# No check-in baggage included     320
# 1 Long layover                    19
# Change airports                    7
# Business class                     4
# No Info                            3
# 1 Short layover                    1
# Red-eye flight                     1
# 2 Long layover                     1
# Name: Additional_Info, dtype: int64
# _____________________________________
# 10262    258
# 10844    212
# 7229     162
# 4804     160
# 4823     131
#         ...
# 14153      1
# 8488       1
# 7826       1
# 6315       1
# 12648      1
# Name: Price, Length: 1870, dtype: int64
# _____________________________________

# %% [markdown]
# From the above value counts we can observe some repeated categories in some columns.

# %% [markdown]
# # Feature Engineering and Data Cleaning

# %% [markdown]
# ### Based on the analysis done above we will do the feature engineering and data cleaning.

# %% [markdown]
# .

# %% [markdown]
# ### The columns Date_of_Journey, Dept_Time and Arrival_Time showing object data type which means python is not able to understand the type of data in this column.Therefore, we have to convert this datatype into timestamp to use them properly for prediction.

# %%
# Converting Date and Time columns from object type to Datetime Type
df_train['Date_of_Journey']=pd.to_datetime(df_train['Date_of_Journey'])
df_train['Dep_Time']=pd.to_datetime(df_train['Dep_Time'])
df_train['Arrival_Time']=pd.to_datetime(df_train['Arrival_Time'])

# %%
#checking dtypes after making the changes
df_train.dtypes
# Out:
# Airline                    object
# Date_of_Journey    datetime64[ns]
# Source                     object
# Destination                object
# Route                      object
# Dep_Time           datetime64[ns]
# Arrival_Time       datetime64[ns]
# Duration                   object
# Total_Stops                object
# Additional_Info            object
# Price                       int64
# dtype: object

# %% [markdown]
# We have data from only 2019, hence we will extract the dates from it

# %%
# Extracting Day from Date_of_Journey column
df_train["Journey_Day"] = pd.to_datetime(df_train.Date_of_Journey, format="%d/%m/%Y").dt.day

# Extracting Month from Date_of_Journey column
df_train["Journey_Month"] = pd.to_datetime(df_train.Date_of_Journey, format="%d/%m/%Y").dt.month

# %% [markdown]
# Now we have converted Date_of_Journey column into integers data type, we can drop this column as it is of no use.

# %%
# Dropping Date_of_Journey column
df_train.drop("Date_of_Journey",axis=1,inplace=True)

# %% [markdown]
# Now the column Duration has values in terms of minutes and hours.

# %%
# Time taken by plane to reach destination is called Duration
# It is the differnce betwwen Departure Time and Arrival time


# Assigning and converting Duration column into list
duration = list(df_train["Duration"])

for i in range(len(duration)):
    if len(duration[i].split()) != 2:    # Check if duration contains only hour or mins
        if "h" in duration[i]:
            duration[i] = duration[i].strip() + " 0m"   # Adds 0 minute
        else:
            duration[i] = "0h " + duration[i]           # Adds 0 hour

duration_hours = []
duration_mins = []
for i in range(len(duration)):
    duration_hours.append(int(duration[i].split(sep = "h")[0]))    # Extract hours from duration
    duration_mins.append(int(duration[i].split(sep = "m")[0].split()[-1]))   # Extracts only minutes from duration

# %%
# Adding duration hours and duration mins to the data set
df_train["Duration_hours"] = duration_hours
df_train["Duration_mins"] = duration_mins

# Dropping Duration column
df_train.drop("Duration",axis=1,inplace=True)

# %% [markdown]
# Let's extract values from Dep_Time. Departure time means when a flight leaves the airport and this column contains hours and minutes so we will extract hours and minutes from Dep_Time.

# %%
# Departure time means the time when the journey starts from the source.

# Extracting Hours from Dep_Time column
df_train["Dep_Hour"] = pd.to_datetime(df_train["Dep_Time"]).dt.hour

# Extracting Minutes from Dep_Time column
df_train["Dep_Min"] = pd.to_datetime(df_train["Dep_Time"]).dt.minute

# %%
# Dropping Dep_Time column
df_train.drop("Dep_Time",axis=1,inplace=True)

# %% [markdown]
# Similarly we can extract hours and minutes from Arrival_Time column and accordingly dropping Arrival_time column.

# %%
# Arrival time is time of arrival at the destination.

# Extracting hour from Arrival_Time
df_train["Arrival_Hour"] = pd.to_datetime(df_train["Arrival_Time"]).dt.hour

# Extracting Minutes from Arrival_Time column
df_train["Arrival_Min"] = pd.to_datetime(df_train["Arrival_Time"]).dt.minute

# Dropping Arrival_Time column
df_train.drop("Arrival_Time",axis=1,inplace=True)

# %% [markdown]
# Now we have extracted values from the respective columns, let's check the data frame after feature engineering.

# %%
df_train.head()
# Out:
#        Airline    Source Destination                  Route Total_Stops  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    non-stop
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR     2 stops
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK     2 stops
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR      1 stop
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL      1 stop
#
#   Additional_Info  Price  Journey_Day  Journey_Month  Duration_hours  \
# 0         No info   3897           24              3               2
# 1         No info   7662            5              1               7
# 2         No info  13882            6              9              19
# 3         No info   6218            5             12               5
# 4         No info  13302            3              1               4
#
#    Duration_mins  Dep_Hour  Dep_Min  Arrival_Hour  Arrival_Min
# 0             50        22       20             1           10
# 1             25         5       50            13           15
# 2              0         9       25             4           25
# 3             25        18        5            23           30
# 4             45        16       50            21           35

# %%
df_train.shape
# Out:
# (10683, 15)

# %% [markdown]
# .

# %% [markdown]
# ### From the analysis done on EDA part for value counts we have observed that some repeated categories in some columns. Will replace it now

# %%
# Replacing "Jet Airways Business" as "Jet Airways" in the column Airline
df_train["Airline"] = df_train["Airline"].replace("Jet Airways Business","Jet Airways")

# Replacing "Multiple carriers Premium economy" as "Multiple carriers" in Airline column
df_train["Airline"] = df_train["Airline"].replace("Multiple carriers Premium economy","Multiple carriers")

# Replacing "Vistara Premium economy" as "Vistara" in Airline column
df_train["Airline"] = df_train["Airline"].replace("Vistara Premium economy","Vistara")

# Replacing "New Delhi" as "Delhi" in Destination column
df_train["Destination"] = df_train["Destination"].replace("New Delhi","Delhi")

# In the column Additional Info, "No Info" and "No info" are one and the same so replace it by "No Info" 
df_train["Additional_Info"] = df_train["Additional_Info"].replace("No info","No Info")

# Replacing "1 Long layover" and "2 Long layover" as "Long layover"in the column Additional Info
df_train["Additional_Info"] = df_train["Additional_Info"].replace(["1 Long layover","2 Long layover"],"Long layover")

# %%
#Checking the value counts again now
val_count=['Airline','Destination','Additional_Info']

for i in val_count:
    print(df_train[i].value_counts())
    print('_____________________________________')
# Out:
# Jet Airways          3855
# IndiGo               2053
# Air India            1752
# Multiple carriers    1209
# SpiceJet              818
# Vistara               482
# Air Asia              319
# GoAir                 194
# Trujet                  1
# Name: Airline, dtype: int64
# _____________________________________
# Cochin       4537
# Banglore     2871
# Delhi        2197
# Hyderabad     697
# Kolkata       381
# Name: Destination, dtype: int64
# _____________________________________
# No Info                         8348
# In-flight meal not included     1982
# No check-in baggage included     320
# Long layover                      20
# Change airports                    7
# Business class                     4
# 1 Short layover                    1
# Red-eye flight                     1
# Name: Additional_Info, dtype: int64
# _____________________________________

# %%
df_train.nunique()
# Out:
# Airline               9
# Source                5
# Destination           5
# Route               128
# Total_Stops           5
# Additional_Info       8
# Price              1870
# Journey_Day           9
# Journey_Month         7
# Duration_hours       44
# Duration_mins        12
# Dep_Hour             24
# Dep_Min              12
# Arrival_Hour         24
# Arrival_Min          12
# dtype: int64

# %% [markdown]
# Now we have the unique numbers in each feature after cleaning the data.

# %% [markdown]
# .

# %% [markdown]
# ### Treating the Null Values by imputation

# %%
# let's check the mode of the categorical columns to fill the null values 
print("The mode of Route is:",df_train["Route"].mode())  # we will fill the null values using its mode
print("The mode of Total_Stops is:",df_train["Total_Stops"].mode())
# Out:
# The mode of Route is: 0    DEL → BOM → COK
# Name: Route, dtype: object
# The mode of Total_Stops is: 0    1 stop
# Name: Total_Stops, dtype: object

# %%
# Filling missing values in Route by its mode DEL → BOM → COK
df_train["Route"] = df_train["Route"].fillna(df_train["Route"].mode()[0])

# Filling missing values in Total_Stops by its mode 1 stop
df_train["Total_Stops"] = df_train["Total_Stops"].fillna(df_train["Total_Stops"].mode()[0])

# %%
df_train.isnull().sum()
# Out:
# Airline            0
# Source             0
# Destination        0
# Route              0
# Total_Stops        0
# Additional_Info    0
# Price              0
# Journey_Day        0
# Journey_Month      0
# Duration_hours     0
# Duration_mins      0
# Dep_Hour           0
# Dep_Min            0
# Arrival_Hour       0
# Arrival_Min        0
# dtype: int64

# %%
sns.heatmap(df_train.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# We can clearly see that we have successfully imputed the null values now

# %%
#checking all the columns in the dataset
df_train.columns
# Out:
# Index(['Airline', 'Source', 'Destination', 'Route', 'Total_Stops',
#        'Additional_Info', 'Price', 'Journey_Day', 'Journey_Month',
#        'Duration_hours', 'Duration_mins', 'Dep_Hour', 'Dep_Min',
#        'Arrival_Hour', 'Arrival_Min'],
#       dtype='object')

# %%
#checking the uniqueness of the target
df_train['Price'].unique()
# Out:
# array([ 3897,  7662, 13882, ...,  9790, 12352, 12648], dtype=int64)

# %%
# Checking the list of counts in target columns
df_train['Price'].value_counts()
# Out:
# 10262    258
# 10844    212
# 7229     162
# 4804     160
# 4823     131
#         ...
# 14153      1
# 8488       1
# 7826       1
# 6315       1
# 12648      1
# Name: Price, Length: 1870, dtype: int64

# %% [markdown]
# # Statistical Summary of the Train DataSet

# %%
df_train.describe()
# Out:
#               Price   Journey_Day  Journey_Month  Duration_hours  \
# count  10683.000000  10683.000000   10683.000000    10683.000000
# mean    9087.064121     12.682205       5.534775       10.246092
# std     4611.359167      8.803701       2.987489        8.495414
# min     1759.000000      3.000000       1.000000        0.000000
# 25%     5277.000000      5.000000       3.000000        2.000000
# 50%     8372.000000      6.000000       5.000000        8.000000
# 75%    12373.000000     21.000000       6.000000       15.000000
# max    79512.000000     27.000000      12.000000       47.000000
#
#        Duration_mins      Dep_Hour       Dep_Min  Arrival_Hour   Arrival_Min
# count   10683.000000  10683.000000  10683.000000  10683.000000  10683.000000
# mean       28.327717     12.490686     24.411214     13.348778     24.690630
# std        16.945400      5.748650     18.767980      6.859125     16.506036
# min         0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        15.000000      8.000000      5.000000      8.000000     10.000000
# 50%        30.000000     11.000000     25.000000     14.000000     25.000000
# 75%        45.000000     18.000000     40.000000     19.000000     35.000000
# max        55.000000     23.000000     55.000000     23.000000     55.000000

# %% [markdown]
# This gives the statistical information of the dataset. The summary of this dataset looks perfect since there is no negative/ invalid values present. It gives the summary of numerical data.
#
# From the above description we can observe the following things
#
# The counts of every column is same which means there are no missing values preent in the dataset. The mean value is greater than the median(50%) in the columns Price, Journey_Day, Duration_hours and Dep_Hour so we can say they are skewed to right. The median(50%) is bit greater than mean in Duration_mins, Dep_Min, Arrival_Hour and Arrival_Min which means they are skewed to left. From the description we can say the minimum price of the flight ticket is Rs.1759 and maximum price is Rs.79512 also the mean is 9087. In summarizing the data we can observe that there is huge difference in maximum and 75% percentile in the columns Price, Arrival_Min, that means huge outliers present in those columns. These differences can also be seen in many other columns. Before going to visualize the data, we will separate numerical and categorical column for better understanding.

# %%
# checking for categorical columns
cat_col=[]
for i in df_train.dtypes.index:
    if df_train.dtypes[i]=='object':
        cat_col.append(i)
print(cat_col)
# Out:
# ['Airline', 'Source', 'Destination', 'Route', 'Total_Stops', 'Additional_Info']

# %%
# checking for numerical columns
num_col=[]
for i in df_train.dtypes.index:
    if df_train.dtypes[i]!='object':
        num_col.append(i)
print(num_col)
# Out:
# ['Price', 'Journey_Day', 'Journey_Month', 'Duration_hours', 'Duration_mins', 'Dep_Hour', 'Dep_Min', 'Arrival_Hour', 'Arrival_Min']

# %% [markdown]
# # Data Visualization

# %% [markdown]
# ## Univariate Analysis of the categorical columns

# %%
# Visualizing the various Airlines present in the dataset
plt.figure(figsize=(8,5))
sns.countplot(df_train["Airline"])
plt.title("Count of flights in different Airlines")
plt.show()

# %% [markdown]
# We can see from the graph that jet airways has the highest counts.

# %%
# Visualizing the source from which place the service begins 
plt.figure(figsize=(5,5))
sns.countplot(df_train["Source"])
plt.title("Count of different Airline source ")
plt.show()

# %% [markdown]
# We can here see that max flights are from Delhi source

# %%
# Visualizing the destination where the service ends 
plt.figure(figsize=(5,5))
sns.countplot(df_train["Destination"])
plt.title("Count of destination where the service ends")
plt.show()

# %% [markdown]
# We can see from the above graph that the max flights are to the destination Cochin

# %%
# Visualizing the Total Stops between the source and the destination
plt.figure(figsize=(5,5))
sns.countplot(df_train["Total_Stops"])
plt.title("Count of Total Stops between the source and the destination")
plt.show()

# %% [markdown]
# The graph represents that the majority of the flights are with one stop, followed by non-stop flights.

# %%
# Visualizing the Additional Information about the flight
plt.figure(figsize=(8,5))
sns.countplot(df_train["Additional_Info"])
plt.title("Count of Additional Information about the flight")
plt.xticks(rotation=75)
plt.show()

# %% [markdown]
# The graph clearly represents that we have multiple classes in the additional_info feature, with no_info with major counts followed by in flight meal and then in flight meal not included.

# %% [markdown]
# ## Univariate Analysis of the numerical columns

# %% [markdown]
# ### Visualizing the disribution of the numerical columns

# %%
plt.figure(figsize=(10,10),facecolor='white')
plotnumber=1
for column in num_col:
    if plotnumber<=9:
        ax=plt.subplot(3,3,plotnumber)
        sns.distplot(df_train[column],color="green")
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# From the plotted graph we can see that the data is not normally distributed and some of the columns has skewness.
#
# The target variable 'Price' is skewed right, Duration_hours is skewed right, Dep_hour is slightly skewed left.
#
# Rest of the columns do now show skewness however the data is not normally distributed

# %% [markdown]
# ## Bivariate Analysis

# %%
# Let's check which Airline is expensive based on Price of tickets

plt.figure(figsize=(10,5))
sns.barplot(df_train["Airline"],df_train["Price"],data=df_train)
plt.title("Checking which Airline is expensive based on ticket price")
plt.show()

# %% [markdown]
# From the plot we can visualize that Jet Airways is the most expensive and SpiceJet and Trujet are the cheapest

# %%
# Let's check the ticket prices in different sources

plt.figure(figsize=(6,5))
sns.barplot(df_train["Source"],df_train["Price"],data=df_train,palette="bright")
plt.title("Checking which source has highest ticket price")
plt.show()

# %% [markdown]
# The tickes prices are expensive in Delhi region compared to others and price is cheaper in Chennai and Mumbai sources.

# %%
# Let's check how prices changes in each destination 

plt.figure(figsize=(6,5))
sns.barplot(df_train["Destination"],df_train["Price"],data=df_train,palette="husl" )
plt.title("Checking deastination based on ticket price")
plt.show()

# %% [markdown]
# The ticket price is high in Cochin destination followed by Bangalore which means they have long distance from the source.

# %%
# Let's check the price vs total stops
plt.figure(figsize=(6,5))
sns.barplot(df_train["Total_Stops"],df_train["Price"],data=df_train,palette="pastel")
plt.title("Checking how price changes based on Stops")
plt.show()

# %% [markdown]
# From the plot we can vislualize that the flights with 4 stops have highest price followed by flights having 3 stops and the flights which have no stops is having very less ticket price compared to others.

# %%
# Let's compare Additional_Info and Price of the flights
plt.figure(figsize=(8,6))
sns.barplot(df_train["Additional_Info"],df_train["Price"],data=df_train)
plt.title("Checking how the prices changes with Additional_Info")
plt.xticks(rotation=50)
plt.show()

# %% [markdown]
# The plot shows that the Business class flights are more expensive compared to others and the flights having the class No check-in baggage included has very least ticket price.

# %%
fig,axes=plt.subplots(2,2,figsize=(15,10))

# Checking relation between Journey_Day and Price
sns.scatterplot(x='Journey_Day',y='Price',ax=axes[0,0],data=df_train)

# Checking relation between Journey_Month and Price
sns.scatterplot(x='Journey_Month',y='Price',ax=axes[0,1],data=df_train)

# Checking relation between Dep_Min and Price
sns.scatterplot(x='Dep_Min',y='Price',ax=axes[1,0],data=df_train)

# Checking relation between Duration_mins and Price
sns.scatterplot(x='Duration_mins',y='Price',ax=axes[1,1],data=df_train)
plt.show()

# %% [markdown]
# From the above plots we can observe the following
#
# While comparing Journey_Day and Price we can see the price of ticket is high in day 3 apart from this there is no much impact of day on ticket price.
#
# While comparing Journey_Month and Price it can be inferred that the flights travelling in the January month are more expensive than others and the flights travelling in April month have very cheap ticket prices.
#
# There in no significance relation between Dep_MIn and Price of the tickets.
#
# In the fourth graph also we can say there is no much impact of Duraation_mins on Price. But we can say duration minutes 10 and 5 have bit high prices compared to others.

# %%
fig,axes=plt.subplots(2,2,figsize=(15,10))

# Checking relation between Duration_hours and Price
sns.stripplot(x='Duration_hours',y='Price',ax=axes[0,0],data=df_train,palette="husl")

# Checking relation between Dep_Hour and Price
sns.stripplot(x='Dep_Hour',y='Price',ax=axes[0,1],data=df_train,palette="bright")

# Checking relation between Arrival_Hour and Price
sns.stripplot(x='Arrival_Hour',y='Price',ax=axes[1,0],data=df_train, palette="ch:.28")

# Checking relation between Arriva_Mins and Price
sns.stripplot(x='Arrival_Min',y='Price',ax=axes[1,1],data=df_train,palette="coolwarm")
plt.show()

# %% [markdown]
# From the above plots we can observe there is no much significance differences in any of the classes with the Price.

# %%
# Checking how the price pays role in Airline on the basis of destination
plt.figure(figsize=(8,6))
sns.swarmplot(x=df_train['Airline'],y=df_train['Price'],hue=df_train["Destination"])
plt.title("Comparing Airline and Price on the basis of Destination")
plt.xticks(rotation=75)
plt.show()

# %% [markdown]
# Here we can conclude that the Jet Airways flights that are destined to Delhi are have more expensive ticket prices compared to others.

# %%
# Checking how the price pays role in Source on the basis of Total_Stops
plt.figure(figsize=(8,6))
sns.stripplot(x=df_train['Source'],y=df_train['Price'],hue=df_train["Total_Stops"])
plt.title("Comparing Source and Price on the basis of Total_Stops")
plt.xticks(rotation=75)
plt.show()

# %% [markdown]
# As we can notice that the flights in the Bangalore source which have only one stop between source and destination have bery expensive ticket price and the flights in Chennai with no stops have very cheap prices compared to other source flights..

# %% [markdown]
# ## Multivariate Analysis

# %%
sns.pairplot(df_train,hue="Price",palette="husl")
plt.show()

# %% [markdown]
# This pair plot gives the pairwise relation between the columns which is plotted on the basis of target variable "Price". Here we can observe the relation between the features and label.

# %% [markdown]
# # Identifying the outliers

# %%
# Identifying the outliers using boxplot
plt.figure(figsize=(15,10),facecolor='white')
plotnumber=1
for column in num_col:
    if plotnumber<=9:
        ax=plt.subplot(3,3,plotnumber)
        sns.boxplot(df_train[column],color="darkorange")
        plt.xlabel(column,fontsize=15)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# The outliers present in Price, Journey_Month and Duration_hours.Since Price is our target column so no need to remove outliers in this two columns.

# %% [markdown]
# # Removing outliers

# %%
# Feature containing outliers
feature = df_train[['Duration_hours','Journey_Month']]
z=np.abs(zscore(feature))

z
# Out:
#        Duration_hours  Journey_Month
# 0            0.970698       0.848503
# 1            0.382117       1.517993
# 2            1.030476       1.159966
# 3            0.617549       2.164201
# 4            0.735265       1.517993
# ...               ...            ...
# 10678        0.970698       1.159966
# 10679        0.970698       0.513758
# 10680        0.852981       0.513758
# 10681        0.970698       1.517993
# 10682        0.264401       1.159966
#
# [10683 rows x 2 columns]

# %%
# Creating new dataframe
new_df_train = df_train[(z<3).all(axis=1)] 
new_df_train
# Out:
#            Airline    Source Destination                  Route Total_Stops  \
# 0           IndiGo  Banglore       Delhi              BLR → DEL    non-stop
# 1        Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR     2 stops
# 2      Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK     2 stops
# 3           IndiGo   Kolkata    Banglore        CCU → NAG → BLR      1 stop
# 4           IndiGo  Banglore       Delhi        BLR → NAG → DEL      1 stop
# ...            ...       ...         ...                    ...         ...
# 10678     Air Asia   Kolkata    Banglore              CCU → BLR    non-stop
# 10679    Air India   Kolkata    Banglore              CCU → BLR    non-stop
# 10680  Jet Airways  Banglore       Delhi              BLR → DEL    non-stop
# 10681      Vistara  Banglore       Delhi              BLR → DEL    non-stop
# 10682    Air India     Delhi      Cochin  DEL → GOI → BOM → COK     2 stops
#
#       Additional_Info  Price  Journey_Day  Journey_Month  Duration_hours  \
# 0             No Info   3897           24              3               2
# 1             No Info   7662            5              1               7
# 2             No Info  13882            6              9              19
# 3             No Info   6218            5             12               5
# 4             No Info  13302            3              1               4
# ...               ...    ...          ...            ...             ...
# 10678         No Info   4107            4              9               2
# 10679         No Info   4145           27              4               2
# 10680         No Info   7229           27              4               3
# 10681         No Info  12648            3              1               2
# 10682         No Info  11753            5              9               8
#
#        Duration_mins  Dep_Hour  Dep_Min  Arrival_Hour  Arrival_Min
# 0                 50        22       20             1           10
# 1                 25         5       50            13           15
# 2                  0         9       25             4           25
# 3                 25        18        5            23           30
# 4                 45        16       50            21           35
# ...              ...       ...      ...           ...          ...
# 10678             30        19       55            22           25
# 10679             35        20       45            23           20
# 10680              0         8       20            11           20
# 10681             40        11       30            14           10
# 10682             20        10       55            19           15
#
# [10617 rows x 15 columns]

# %% [markdown]
# ### This is the new dataframe after removing the outliers. Here we have removed the outliers whose Zscore is less than 3.

# %% [markdown]
# # Checking skewness in the data

# %%
new_df_train.skew().sort_values()
# Out:
# Arrival_Hour     -0.361250
# Duration_mins    -0.097354
# Dep_Hour          0.103798
# Arrival_Min       0.107805
# Dep_Min           0.164551
# Journey_Day       0.367029
# Journey_Month     0.628224
# Duration_hours    0.761022
# Price             1.824502
# dtype: float64

# %% [markdown]
# We can find the columns Price, Journey_Month and Duration_hours have skewness but will remove skewness in Duration_hours and Journey_Month as they are numerical columns.

# %% [markdown]
# # Removing skewness using log transformation

# %%
new_df_train["Duration_hours"] = np.log1p(new_df_train["Duration_hours"])
new_df_train["Journey_Month"] = np.log1p(new_df_train["Journey_Month"])

# %%
#checking skewness again
new_df_train.skew().sort_values()
# Out:
# Journey_Month    -0.533689
# Arrival_Hour     -0.361250
# Duration_hours   -0.109197
# Duration_mins    -0.097354
# Dep_Hour          0.103798
# Arrival_Min       0.107805
# Dep_Min           0.164551
# Journey_Day       0.367029
# Price             1.824502
# dtype: float64

# %% [markdown]
# We can observe the skewness has been removed in Duration_hours and Journey_Month columns. Let's visualize it.

# %% [markdown]
# # Encoding the Categorical columns

# %%
le=LabelEncoder()
new_df_train[cat_col]= new_df_train[cat_col].apply(le.fit_transform)
new_df_train
# Out:
#        Airline  Source  Destination  Route  Total_Stops  Additional_Info  \
# 0            3       0            2     18            4                5
# 1            1       3            0     84            1                5
# 2            4       2            1    118            1                5
# 3            3       3            0     91            0                5
# 4            3       0            2     29            0                5
# ...        ...     ...          ...    ...          ...              ...
# 10678        0       3            0     64            4                5
# 10679        1       3            0     64            4                5
# 10680        4       0            2     18            4                5
# 10681        8       0            2     18            4                5
# 10682        1       2            1    108            1                5
#
#        Price  Journey_Day  Journey_Month  Duration_hours  Duration_mins  \
# 0       3897           24       1.386294        1.098612             50
# 1       7662            5       0.693147        2.079442             25
# 2      13882            6       2.302585        2.995732              0
# 3       6218            5       2.564949        1.791759             25
# 4      13302            3       0.693147        1.609438             45
# ...      ...          ...            ...             ...            ...
# 10678   4107            4       2.302585        1.098612             30
# 10679   4145           27       1.609438        1.098612             35
# 10680   7229           27       1.609438        1.386294              0
# 10681  12648            3       0.693147        1.098612             40
# 10682  11753            5       2.302585        2.197225             20
#
#        Dep_Hour  Dep_Min  Arrival_Hour  Arrival_Min
# 0            22       20             1           10
# 1             5       50            13           15
# 2             9       25             4           25
# 3            18        5            23           30
# 4            16       50            21           35
# ...         ...      ...           ...          ...
# 10678        19       55            22           25
# 10679        20       45            23           20
# 10680         8       20            11           20
# 10681        11       30            14           10
# 10682        10       55            19           15
#
# [10617 rows x 15 columns]

# %% [markdown]
# Now we have converted the categorical columns into numerical columns using label encoding method.

# %% [markdown]
# # Checking the correlation between feature and label

# %%
cor =new_df_train.corr()
cor
# Out:
#                   Airline    Source  Destination     Route  Total_Stops  \
# Airline          1.000000 -0.013641     0.055391  0.021921    -0.010497
# Source          -0.013641  1.000000    -0.434677  0.404009    -0.225922
# Destination      0.055391 -0.434677     1.000000 -0.230755     0.510659
# Route            0.021921  0.404009    -0.230755  1.000000    -0.439372
# Total_Stops     -0.010497 -0.225922     0.510659 -0.439372     1.000000
# Additional_Info -0.056234 -0.034128     0.115602  0.002232     0.234493
# Price            0.024773  0.016718    -0.263334  0.163635    -0.572413
# Journey_Day      0.025366  0.007158     0.007309  0.096042     0.043711
# Journey_Month    0.005402  0.062011    -0.061873  0.076196    -0.048791
# Duration_hours  -0.076407  0.149110    -0.493825  0.383743    -0.806706
# Duration_mins   -0.043858 -0.145872     0.021895 -0.229643     0.182696
# Dep_Hour        -0.028238  0.059469    -0.088810 -0.070005     0.038512
# Dep_Min         -0.070340 -0.055929     0.097052 -0.066420     0.049105
# Arrival_Hour    -0.005868  0.026144    -0.058190  0.011514    -0.095213
# Arrival_Min     -0.087465  0.021640     0.006954 -0.174071     0.176915
#
#                  Additional_Info     Price  Journey_Day  Journey_Month  \
# Airline                -0.056234  0.024773     0.025366       0.005402
# Source                 -0.034128  0.016718     0.007158       0.062011
# Destination             0.115602 -0.263334     0.007309      -0.061873
# Route                   0.002232  0.163635     0.096042       0.076196
# Total_Stops             0.234493 -0.572413     0.043711      -0.048791
# Additional_Info         1.000000 -0.114590    -0.012301      -0.025319
# Price                  -0.114590  1.000000    -0.163765      -0.013511
# Journey_Day            -0.012301 -0.163765     1.000000      -0.097582
# Journey_Month          -0.025319 -0.013511    -0.097582       1.000000
# Duration_hours         -0.255705  0.605075    -0.041874       0.062242
# Duration_mins           0.059669 -0.122893    -0.008671      -0.023684
# Dep_Hour               -0.052282  0.011430    -0.002628       0.020587
# Dep_Min                 0.008984 -0.025585    -0.017421      -0.005264
# Arrival_Hour           -0.005902  0.021107    -0.001501      -0.005743
# Arrival_Min             0.044179 -0.088909    -0.021901      -0.031453
#
#                  Duration_hours  Duration_mins  Dep_Hour   Dep_Min  \
# Airline               -0.076407      -0.043858 -0.028238 -0.070340
# Source                 0.149110      -0.145872  0.059469 -0.055929
# Destination           -0.493825       0.021895 -0.088810  0.097052
# Route                  0.383743      -0.229643 -0.070005 -0.066420
# Total_Stops           -0.806706       0.182696  0.038512  0.049105
# Additional_Info       -0.255705       0.059669 -0.052282  0.008984
# Price                  0.605075      -0.122893  0.011430 -0.025585
# Journey_Day           -0.041874      -0.008671 -0.002628 -0.017421
# Journey_Month          0.062242      -0.023684  0.020587 -0.005264
# Duration_hours         1.000000      -0.166151  0.000980 -0.033117
# Duration_mins         -0.166151       1.000000 -0.029934  0.091393
# Dep_Hour               0.000980      -0.029934  1.000000 -0.026077
# Dep_Min               -0.033117       0.091393 -0.026077  1.000000
# Arrival_Hour           0.060794      -0.115378  0.010967  0.043613
# Arrival_Min           -0.127237       0.151280  0.068350 -0.018693
#
#                  Arrival_Hour  Arrival_Min
# Airline             -0.005868    -0.087465
# Source               0.026144     0.021640
# Destination         -0.058190     0.006954
# Route                0.011514    -0.174071
# Total_Stops         -0.095213     0.176915
# Additional_Info     -0.005902     0.044179
# Price                0.021107    -0.088909
# Journey_Day         -0.001501    -0.021901
# Journey_Month       -0.005743    -0.031453
# Duration_hours       0.060794    -0.127237
# Duration_mins       -0.115378     0.151280
# Dep_Hour             0.010967     0.068350
# Dep_Min              0.043613    -0.018693
# Arrival_Hour         1.000000    -0.155330
# Arrival_Min         -0.155330     1.000000

# %%
plt.figure(figsize=(20,15))    
sns.heatmap(new_df_train.corr(),linewidths=.1,vmin=-1, vmax=1,fmt='.1g',linecolor="black",annot=True,annot_kws={'size':10},cmap="YlGnBu")
plt.yticks(rotation=0);

# %% [markdown]
# This heatmap shows the correlation matrix by visualizing the data. we can observe the relation between one feature to other.
#
# This heat map contains both positive and negative correlation. The feature Duration_hours is highly positively correlated with the target variable Price. The feature Total_Stops is highly Negatively correlated with the label. The features Duration_ours and Total_Stops, Duration_hours and Destination are highly negatively correlated with each other. This may lead to multicollinearity problem so we will check the VIF value to solve this, if we get the features having VIF more than 10 then we can drop those columns.

# %%
cor['Price'].sort_values(ascending=False)
# Out:
# Price              1.000000
# Duration_hours     0.605075
# Route              0.163635
# Airline            0.024773
# Arrival_Hour       0.021107
# Source             0.016718
# Dep_Hour           0.011430
# Journey_Month     -0.013511
# Dep_Min           -0.025585
# Arrival_Min       -0.088909
# Additional_Info   -0.114590
# Duration_mins     -0.122893
# Journey_Day       -0.163765
# Destination       -0.263334
# Total_Stops       -0.572413
# Name: Price, dtype: float64

# %% [markdown]
# # Visualizing the correlation between label and features using bar plot

# %%
plt.figure(figsize=(22,7))
new_df_train.corr()['Price'].sort_values(ascending=False).drop(['Price']).plot(kind='bar',color='g')
plt.xlabel('Feature',fontsize=15)
plt.ylabel('Target',fontsize=15)
plt.title('correlation between label and feature using bar plot',fontsize=18)
plt.show()

# %% [markdown]
# # Data Pre-processing

# %% [markdown]
# ### 1. Splitting feature and label into x and y

# %%
x = new_df_train.drop("Price", axis=1)
y = new_df_train["Price"]

# %% [markdown]
# ### 2. Feature Scaling using Standard Scalarization

# %%
scaler = StandardScaler()
x = pd.DataFrame(scaler.fit_transform(x), columns=x.columns)
x
# Out:
#         Airline    Source  Destination     Route  Total_Stops  \
# 0     -0.345488 -1.655042     0.812707 -1.544003     1.402360
# 1     -1.464134  0.888124    -1.157048  0.254498    -0.253797
# 2      0.213836  0.040402    -0.172170  1.180998    -0.253797
# 3     -0.345488  0.888124    -1.157048  0.445248    -0.805850
# 4     -0.345488 -1.655042     0.812707 -1.244253    -0.805850
# ...         ...       ...          ...       ...          ...
# 10612 -2.023458  0.888124    -1.157048 -0.290502     1.402360
# 10613 -1.464134  0.888124    -1.157048 -0.290502     1.402360
# 10614  0.213836 -1.655042     0.812707 -1.544003     1.402360
# 10615  2.451129 -1.655042     0.812707 -1.544003     1.402360
# 10616 -1.464134  0.040402    -0.172170  0.908498    -0.253797
#
#        Additional_Info  Journey_Day  Journey_Month  Duration_hours  \
# 0             0.424603     1.286176      -0.754967       -1.183984
# 1             0.424603    -0.873920      -2.141814       -0.009867
# 2             0.424603    -0.760231       1.078344        1.086993
# 3             0.424603    -0.873920       1.603281       -0.354241
# 4             0.424603    -1.101299      -2.141814       -0.572492
# ...                ...          ...            ...             ...
# 10612         0.424603    -0.987609       1.078344       -1.183984
# 10613         0.424603     1.627244      -0.308502       -1.183984
# 10614         0.424603     1.627244      -0.308502       -0.839609
# 10615         0.424603    -1.101299      -2.141814       -1.183984
# 10616         0.424603    -0.873920       1.078344        0.131127
#
#        Duration_mins  Dep_Hour   Dep_Min  Arrival_Hour  Arrival_Min
# 0           1.274299  1.649475 -0.235894     -1.794784    -0.889208
# 1          -0.201145 -1.312186  1.362715     -0.046050    -0.586465
# 2          -1.676590 -0.615325  0.030541     -1.357601     0.019019
# 3          -0.201145  0.952614 -1.035199      1.411228     0.321762
# 4           0.979210  0.604183  1.362715      1.119772     0.624504
# ...              ...       ...       ...           ...          ...
# 10612       0.093944  1.126829  1.629150      1.265500     0.019019
# 10613       0.389033  1.301044  1.096280      1.411228    -0.283723
# 10614      -1.676590 -0.789540 -0.235894     -0.337506    -0.283723
# 10615       0.684121 -0.266894  0.296976      0.099677    -0.889208
# 10616      -0.496234 -0.441109  1.629150      0.828317    -0.586465
#
# [10617 rows x 14 columns]

# %% [markdown]
# We have scaled the data using standard scalarizaion method to overcome with the issue of data biasness.

# %% [markdown]
# ### 3. Checking VIF (Multicolinearity)

# %%
vif = pd.DataFrame()
vif["VIF values"] = [variance_inflation_factor(x.values,i)
              for i in range(len(x.columns))]
vif["Features"] = x.columns

# Let's check the values
vif
# Out:
#     VIF values         Features
# 0     1.044046          Airline
# 1     1.511995           Source
# 2     1.762240      Destination
# 3     1.583264            Route
# 4     3.330957      Total_Stops
# 5     1.107199  Additional_Info
# 6     1.035552      Journey_Day
# 7     1.022110    Journey_Month
# 8     3.175330   Duration_hours
# 9     1.125160    Duration_mins
# 10    1.035078         Dep_Hour
# 11    1.030532          Dep_Min
# 12    1.048109     Arrival_Hour
# 13    1.107147      Arrival_Min

# %% [markdown]
# Here we can notice the VIF value is less than 10 in all the columns. We are free from multicollinearity problem now so let's move to build our machine learning models.

# %% [markdown]
# # Machine Learning

# %% [markdown]
# ### Finding Best Random State

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.model_selection import train_test_split

# %% [markdown]
# For test_size=.30

# %%
maxAccu=0
maxRS=0
for i in range(1,200):
    x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=.30, random_state=i)
    mod = RandomForestRegressor()
    mod.fit(x_train, y_train)
    pred = mod.predict(x_test)
    acc=r2_score(y_test, pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print("Maximum r2 score is ",maxAccu," on Random_state ",maxRS)
# Out:
# Maximum r2 score is  0.9190559781302241  on Random_state  181

# %% [markdown]
# We have got the r2 score of 91.9% at the randomstate of 181

# %% [markdown]
# For test_size=.20

# %%
maxAccu=0
maxRS=0
for i in range(1,200):
    x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=.20, random_state=i)
    mod = RandomForestRegressor()
    mod.fit(x_train, y_train)
    pred = mod.predict(x_test)
    acc=r2_score(y_test, pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print("Maximum r2 score is ",maxAccu," on Random_state ",maxRS)
# Out:
# Maximum r2 score is  0.9294118905258066  on Random_state  186

# %% [markdown]
# We have got the r2 score of 92.9% at the random_state of 186

# %% [markdown]
# Hence we will take random_state as 186 with test_size = 0.20

# %% [markdown]
# ## Feature Importance

# %%
# Lets ckeck the feature importance using Random Forest Regressor

RFR = RandomForestRegressor()
RFR.fit(x_train, y_train)
importances = pd.DataFrame({'Features':x.columns, 'Importance':np.round(RFR.feature_importances_,3)})
importances = importances.sort_values('Importance', ascending=False).set_index('Features')
importances
# Out:
#                  Importance
# Features
# Duration_hours        0.434
# Journey_Day           0.121
# Airline               0.103
# Journey_Month         0.073
# Additional_Info       0.061
# Total_Stops           0.049
# Route                 0.040
# Arrival_Hour          0.029
# Dep_Hour              0.028
# Dep_Min               0.018
# Duration_mins         0.016
# Arrival_Min           0.016
# Source                0.007
# Destination           0.007

# %% [markdown]
# With the help of Random Forest Regressor we are able to list down the importance or priority given to a feature as per it's involvement or weightage in predicting our label.

# %% [markdown]
# ## Creating train test split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=186)

# %%
mod = RandomForestRegressor()

# %%
mod.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
pred_test = mod.predict(x_test)

# %%
print(r2_score(y_test,pred_test))
# Out:
# 0.9257080690001698

# %% [markdown]
# We will draw the regression plot to see the best fit line

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test, y=pred_test, color='r')
plt.plot(y_test,y_test,color='b')
plt.xlabel('Actual Price', fontsize=14)
plt.ylabel('Predicted Price', fontsize=14)
plt.title('RandomForestRegressor',fontsize=18)
plt.show()

# %% [markdown]
# The best fit line seems to be covering most of the data points

# %%
# importing all the required libraries

from sklearn.linear_model import LinearRegression,Lasso,Ridge,ElasticNet
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import SGDRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import ExtraTreesRegressor

from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV

# %%
# creating a function to run all the regressors

def regressor(model, x, y):
    x_train,x_test,y_train,y_test = train_test_split(x, y, test_size=0.2, random_state=186)
    
    # Training the model
    model.fit(x_train, y_train)
    
    # Predicting y_test
    pred = model.predict(x_test)
    
    # Root Mean Square Error (RMSE)
    rmse = mean_squared_error(y_test, pred, squared=False)
    print("Root Mean Square Error is:", rmse)
    
    # R2 score
    r2 = r2_score(y_test, pred, multioutput='variance_weighted')*100
    print("R2 Score is:", r2)
    
    # Cross Validation Score
    cv_score = (cross_val_score(model, x, y, cv=5).mean())*100
    print("Cross Validation Score is:", cv_score)
    
    # Result of r2 score - cv score
    result = r2 - cv_score
    print("R2 Score - Cross Validation Score is", result)

# %% [markdown]
# ### Linear Regression

# %%
model=LinearRegression()
regressor(model, x, y)
# Out:
# Root Mean Square Error is: 3136.9989289211244
# R2 Score is: 49.63096635375916
# Cross Validation Score is: 43.165585526907165
# R2 Score - Cross Validation Score is 6.465380826851998

# %% [markdown]
# ### L1 -- Lasso Regression

# %%
model=Lasso(alpha=0.001)
regressor(model, x, y)
# Out:
# Root Mean Square Error is: 3136.9988716252083
# R2 Score is: 49.63096819369596
# Cross Validation Score is: 43.16558651274626
# R2 Score - Cross Validation Score is 6.4653816809497044

# %% [markdown]
# ### L2 -- Ridge Regression

# %%
model=Ridge(alpha=0.001)
regressor(model, x, y)
# Out:
# Root Mean Square Error is: 3136.998930591503
# R2 Score is: 49.63096630011851
# Cross Validation Score is: 43.16558556746779
# R2 Score - Cross Validation Score is 6.465380732650722

# %% [markdown]
# ### Elastic Net

# %%
model=ElasticNet(alpha=0.001)
regressor(model, x, y)
# Out:
# Root Mean Square Error is: 3137.0063596260648
# R2 Score is: 49.63072773214729
# Cross Validation Score is: 43.165745857213125
# R2 Score - Cross Validation Score is 6.464981874934168

# %% [markdown]
# ### Support Vector Regression

# %%
model=SVR(kernel='rbf')
regressor(model, x, y)
# Out:
# Root Mean Square Error is: 4310.721619954531
# R2 Score is: 4.8881052877224445
# Cross Validation Score is: 3.702000837936117
# R2 Score - Cross Validation Score is 1.1861044497863276

# %%
model=SVR(kernel='poly')
regressor(model, x, y)
# Out:
# Root Mean Square Error is: 4297.177035182223
# R2 Score is: 5.484862558187542
# Cross Validation Score is: 3.9897843438588194
# R2 Score - Cross Validation Score is 1.4950782143287227

# %%
model=SVR(kernel='linear')
regressor(model, x, y)
# Out:
# Root Mean Square Error is: 3333.141679198713
# R2 Score is: 43.13534265903204
# Cross Validation Score is: 36.48888034999723
# R2 Score - Cross Validation Score is 6.64646230903481

# %% [markdown]
# ### Decision Tree Regressor

# %%
model=DecisionTreeRegressor(random_state=186)
regressor(model, x, y)
# Out:
# Root Mean Square Error is: 1585.4967255267998
# R2 Score is: 87.13334735052157
# Cross Validation Score is: 79.72726114751487
# R2 Score - Cross Validation Score is 7.4060862030067085

# %%
model=DecisionTreeRegressor()
regressor(model, x, y)
# Out:
# Root Mean Square Error is: 1599.4993848859308
# R2 Score is: 86.90507447574741
# Cross Validation Score is: 80.44504724689361
# R2 Score - Cross Validation Score is 6.460027228853804

# %% [markdown]
# ### Random Forest Regressor

# %%
model=RandomForestRegressor()
regressor(model, x, y)
# Out:
# Root Mean Square Error is: 1187.3758190323958
# R2 Score is: 92.78375485256166
# Cross Validation Score is: 87.95370908374672
# R2 Score - Cross Validation Score is 4.830045768814941

# %%
model=RandomForestRegressor(random_state=186)
regressor(model, x, y)
# Out:
# Root Mean Square Error is: 1180.5200722359793
# R2 Score is: 92.86684552072407
# Cross Validation Score is: 88.17914145700982
# R2 Score - Cross Validation Score is 4.68770406371425

# %% [markdown]
# ### K Neighbors Regressor

# %%
model=KNeighborsRegressor()
regressor(model, x, y)
# Out:
# Root Mean Square Error is: 2141.788257851118
# R2 Score is: 76.52054864721592
# Cross Validation Score is: 72.53697696458616
# R2 Score - Cross Validation Score is 3.9835716826297585

# %% [markdown]
# ### SGD Regressor

# %%
model=SGDRegressor()
regressor(model, x, y)
# Out:
# Root Mean Square Error is: 3133.892059808211
# R2 Score is: 49.73068745978832
# Cross Validation Score is: 42.958616372818334
# R2 Score - Cross Validation Score is 6.772071086969987

# %% [markdown]
# ### Gradient Boosting Regressor

# %%
model=GradientBoostingRegressor()
regressor(model, x, y)
# Out:
# Root Mean Square Error is: 1706.273489603055
# R2 Score is: 85.09842529550181
# Cross Validation Score is: 80.895283884208
# R2 Score - Cross Validation Score is 4.203141411293814

# %% [markdown]
# ### Ada Boost Regressor

# %%
model=AdaBoostRegressor()
regressor(model, x, y)
# Out:
# Root Mean Square Error is: 3772.697247821107
# R2 Score is: 27.148451318299337
# Cross Validation Score is: 31.612812546068746
# R2 Score - Cross Validation Score is -4.464361227769409

# %%
model=AdaBoostRegressor(random_state=186)
regressor(model, x, y)
# Out:
# Root Mean Square Error is: 4009.0561604707873
# R2 Score is: 17.734231690506007
# Cross Validation Score is: 33.02207023629854
# R2 Score - Cross Validation Score is -15.287838545792532

# %% [markdown]
# ### Extra Trees Regressor

# %%
model=ExtraTreesRegressor()
regressor(model, x, y)
# Out:
# Root Mean Square Error is: 1168.3318131676733
# R2 Score is: 93.01337742263
# Cross Validation Score is: 89.94301633998909
# R2 Score - Cross Validation Score is 3.0703610826409147

# %%
model=ExtraTreesRegressor(random_state=186)
regressor(model, x, y)
# Out:
# Root Mean Square Error is: 1160.031378554766
# R2 Score is: 93.11229795290096
# Cross Validation Score is: 89.80619431795995
# R2 Score - Cross Validation Score is 3.3061036349410102

# %% [markdown]
# Comparing all the above the Extra Trees Regressor gives the best results since the R2 Score - Cross Validation Score are closest along with higher Cross Validation Score and the highest R2 score comparing all the models.

# %% [markdown]
# # Hyper parameter tuning

# %%
#ExtraTreesRegressor?

# %%
ExtraTreesRegressor().get_params().keys()
# Out:
# dict_keys(['bootstrap', 'ccp_alpha', 'criterion', 'max_depth', 'max_features', 'max_leaf_nodes', 'max_samples', 'min_impurity_decrease', 'min_samples_leaf', 'min_samples_split', 'min_weight_fraction_leaf', 'n_estimators', 'n_jobs', 'oob_score', 'random_state', 'verbose', 'warm_start'])

# %%
# creating parameters list to pass into GridSearchCV

parameters = {'criterion' : ['squared_error', 'absolute_error'],
              'max_features' : ['auto', 'sqrt', 'log2'],
              'n_jobs' : [-2, -1, 1],
              'random_state' : [None, 186]}

# %%
GCV = GridSearchCV(ExtraTreesRegressor(), parameters, cv=5)

# %%
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=ExtraTreesRegressor(),
#              param_grid={'criterion': ['squared_error', 'absolute_error'],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_jobs': [-2, -1, 1], 'random_state': [None, 186]})

# %%
GCV.best_params_      # printing best parameters found by GridSearchCV
# Out:
# {'criterion': 'squared_error',
#  'max_features': 'auto',
#  'n_jobs': -1,
#  'random_state': None}

# %% [markdown]
# We got the best parameters using Gridsearch CV

# %%
final_model = ExtraTreesRegressor(criterion = 'squared_error', max_features = 'auto', n_jobs = -1, random_state = None)

# %%
final_fit = final_model.fit(x_train,y_train)   # final fit

# %%
final_pred = final_model.predict(x_test)   # predicting with best parameters

# %%
best_r2=r2_score(y_test,final_pred,multioutput='variance_weighted')*100   # checking final r2_score
print("R2 score for the Best Model is:", best_r2)
# Out:
# R2 score for the Best Model is: 92.74577828390655

# %%
final_cv_score = (cross_val_score(final_model, x, y, cv=8).mean())*100
print("Cross Validation Score is:", final_cv_score)
# Out:
# Cross Validation Score is: 89.42672880324909

# %%
final_rmse = mean_squared_error(y_test, final_pred, squared=False)
print("Root Mean Square Error is:", final_rmse)
# Out:
# Root Mean Square Error is: 1190.4960905541286

# %% [markdown]
# We used Hyper Parameter Tuning on the final model to obtained the best r2_score and CV score.

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test, y=final_pred, color='r')
plt1 = max(max(final_pred), max(y_test))
plt2 = min(min(final_pred), min(y_test))
plt.plot([plt1, plt2], [plt1, plt2], 'b-')
plt.xlabel('Actual Price', fontsize=14)
plt.ylabel('Predicted Price', fontsize=14)
plt.title('ExtraTreesRegressor',fontsize=18)
plt.show()

# %% [markdown]
# Plotting the Final model Actual AveragePrice vs Predicted AveragePrice

# %% [markdown]
# # Saving the model in pickle Format

# %%
# pickeling or serialization of a file
import pickle
filename = 'Flight_Price_Prediction_final_model.pkl'
pickle.dump(final_model, open(filename, 'wb'))

# %% [markdown]
# Saving the best regression model using pickle

# %% [markdown]
# # Prediction Conclusion:

# %%
import numpy as np
a=np.array(y_test)
predicted=np.array(final_model.predict(x_test))
df_comparison = pd.DataFrame({"original":a,"predicted":predicted},index= range(len(a)))
df_comparison
# Out:
#       original  predicted
# 0         5963    6839.68
# 1         7408    8886.76
# 2         9564    9564.00
# 3         6781    9289.08
# 4         3841    3838.34
# ...        ...        ...
# 2119      7452    7875.95
# 2120     10441    9598.93
# 2121     15129   15105.90
# 2122      4437    5619.88
# 2123      2753    2225.12
#
# [2124 rows x 2 columns]

# %% [markdown]
# # Test Data

# %%
test_df = pd.read_excel("Flight_Price_Prediction_Test_set.xlsx")
test_df.head()
# Out:
#              Airline Date_of_Journey    Source Destination            Route  \
# 0        Jet Airways       6/06/2019     Delhi      Cochin  DEL → BOM → COK
# 1             IndiGo      12/05/2019   Kolkata    Banglore  CCU → MAA → BLR
# 2        Jet Airways      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 3  Multiple carriers      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 4           Air Asia      24/06/2019  Banglore       Delhi        BLR → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops              Additional_Info
# 0    17:30  04:25 07 Jun  10h 55m      1 stop                      No info
# 1    06:20         10:20       4h      1 stop                      No info
# 2    19:15  19:00 22 May  23h 45m      1 stop  In-flight meal not included
# 3    08:00         21:00      13h      1 stop                      No info
# 4    23:55  02:45 25 Jun   2h 50m    non-stop                      No info

# %% [markdown]
# This test dataset has no target variable, we need to use our past data(trained data) to get the ticket price prediction.

# %%
# Checking the dimension of the dataset
test_df.shape
# Out:
# (2671, 10)

# %% [markdown]
# There are 2671 rows and 10 columns are there in test dataset. All the columns are independent and there is no dependent variable in this dataset.

# %%
# Checking how many columns are there in the dataset
test_df.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Dep_Time', 'Arrival_Time', 'Duration', 'Total_Stops',
#        'Additional_Info'],
#       dtype='object')

# %%
# Checking the types of the dataset
test_df.dtypes
# Out:
# Airline            object
# Date_of_Journey    object
# Source             object
# Destination        object
# Route              object
# Dep_Time           object
# Arrival_Time       object
# Duration           object
# Total_Stops        object
# Additional_Info    object
# dtype: object

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# The columns Date_of_Journey, Dept_Time and Arrival_Time showing object data type which means python is not able to understand the type of data in this column.
#
# Therefore, we have to convert this datatype into timestamp to use them properly for prediction.

# %%
# Converting Date and Time columns from object type to Date Type
test_df['Date_of_Journey']=pd.to_datetime(test_df['Date_of_Journey'])
test_df['Dep_Time']=pd.to_datetime(test_df['Dep_Time'])
test_df['Arrival_Time']=pd.to_datetime(test_df['Arrival_Time'])

# %%
# Again checking the type of dataset
test_df.dtypes
# Out:
# Airline                    object
# Date_of_Journey    datetime64[ns]
# Source                     object
# Destination                object
# Route                      object
# Dep_Time           datetime64[ns]
# Arrival_Time       datetime64[ns]
# Duration                   object
# Total_Stops                object
# Additional_Info            object
# dtype: object

# %%
# Extracting Day from Date_of_Journey column
test_df["Journey_Day"] = pd.to_datetime(test_df.Date_of_Journey, format="%d/%m/%Y").dt.day

# Extracting Month from Date_of_Journey column
test_df["Journey_Month"] = pd.to_datetime(test_df.Date_of_Journey, format="%d/%m/%Y").dt.month

# %%
# Dropping Date_of_Journey column
test_df.drop("Date_of_Journey",axis=1,inplace=True)

# %% [markdown]
# So here the day and month has been extracted from date of journey
#
# The column Duration has values in terms of minutes and hours. Duration means the time taken by the pane to reach the destination and it is the difference between Departure time and the arrival time. Now let's extract hours and minutes from Duration.

# %%
# Converting duration column into list
duration=list(test_df["Duration"])

for i in range(len(duration)):
    
    # Checking if duration contains oly hour or minute
    if len(duration[i].split()) != 2:
        if 'h' in duration[i]:
            duration[i]=duration[i].strip()+' 0m'   
        else:
            duration[i]="0h "+ duration[i]
duration_hours=[]
duration_mins=[]
for i in range(len(duration)):
    
    # Extracting hours feom Duration
    duration_hours.append(int(duration[i].split(sep="h")[0]))
    
    # Extracting minutes from Duration
    duration_mins.append(int(duration[i].split(sep="m")[0].split()[-1]))

# %%
# Adding duration hours and duration mins to the data set
test_df["Duration_hours"] = duration_hours
test_df["Duration_mins"] = duration_mins

# Dropping Duration column
test_df.drop("Duration",axis=1,inplace=True)

# %%
# Departure time means the time when the journey starts from the source.

# Extracting Hours from Dep_Time column
test_df["Dep_Hour"] = pd.to_datetime(test_df["Dep_Time"]).dt.hour

# Extracting Minutes from Dep_Time column
test_df["Dep_Min"] = pd.to_datetime(test_df["Dep_Time"]).dt.minute

# %%
# Dropping Dep_Time column
test_df.drop("Dep_Time",axis=1,inplace=True)

# %% [markdown]
# Similarly we can extract hours and minutes from Arrival_Time column and accordingly dropping Arrival_time column.

# %%
# Arrival time is time of arrival at the destination.

# Extracting hour from Arrival_Time
test_df["Arrival_Hour"] = pd.to_datetime(test_df["Arrival_Time"]).dt.hour

# Extracting Minutes from Arrival_Time column
test_df["Arrival_Min"] = pd.to_datetime(test_df["Arrival_Time"]).dt.minute

# Dropping Arrival_Time column
test_df.drop("Arrival_Time",axis=1,inplace=True)

# %% [markdown]
# Now we have extracted values from the respective columns, let's check the data frame after feature engineering.

# %%
# Checking dataset again
test_df.head()
# Out:
#              Airline    Source Destination            Route Total_Stops  \
# 0        Jet Airways     Delhi      Cochin  DEL → BOM → COK      1 stop
# 1             IndiGo   Kolkata    Banglore  CCU → MAA → BLR      1 stop
# 2        Jet Airways     Delhi      Cochin  DEL → BOM → COK      1 stop
# 3  Multiple carriers     Delhi      Cochin  DEL → BOM → COK      1 stop
# 4           Air Asia  Banglore       Delhi        BLR → DEL    non-stop
#
#                Additional_Info  Journey_Day  Journey_Month  Duration_hours  \
# 0                      No info            6              6              10
# 1                      No info            5             12               4
# 2  In-flight meal not included           21              5              23
# 3                      No info           21              5              13
# 4                      No info           24              6               2
#
#    Duration_mins  Dep_Hour  Dep_Min  Arrival_Hour  Arrival_Min
# 0             55        17       30             4           25
# 1              0         6       20            10           20
# 2             45        19       15            19            0
# 3              0         8        0            21            0
# 4             50        23       55             2           45

# %%
test_df.shape
# Out:
# (2671, 14)

# %%
# Checking the value counts of each columns
for i in test_df.columns:
        print(test_df[i].value_counts())
        print('_____________________')
# Out:
# Jet Airways                          897
# IndiGo                               511
# Air India                            440
# Multiple carriers                    347
# SpiceJet                             208
# Vistara                              129
# Air Asia                              86
# GoAir                                 46
# Multiple carriers Premium economy      3
# Vistara Premium economy                2
# Jet Airways Business                   2
# Name: Airline, dtype: int64
# _____________________
# Delhi       1145
# Kolkata      710
# Banglore     555
# Mumbai       186
# Chennai       75
# Name: Source, dtype: int64
# _____________________
# Cochin       1145
# Banglore      710
# Delhi         317
# New Delhi     238
# Hyderabad     186
# Kolkata        75
# Name: Destination, dtype: int64
# _____________________
# DEL → BOM → COK                624
# BLR → DEL                      389
# CCU → BOM → BLR                253
# CCU → BLR                      172
# BOM → HYD                      164
#                               ...
# BLR → BOM → IDR → GWL → DEL      1
# BLR → GOI → DEL                  1
# CCU → PAT → BLR                  1
# BLR → VGA → DEL                  1
# BOM → GOI → PNQ → HYD            1
# Name: Route, Length: 100, dtype: int64
# _____________________
# 1 stop      1431
# non-stop     849
# 2 stops      379
# 3 stops       11
# 4 stops        1
# Name: Total_Stops, dtype: int64
# _____________________
# No info                         2148
# In-flight meal not included      444
# No check-in baggage included      76
# 1 Long layover                     1
# Business class                     1
# Change airports                    1
# Name: Additional_Info, dtype: int64
# _____________________
# 6     561
# 3     378
# 5     374
# 15    267
# 21    257
# 24    255
# 27    220
# 18    204
# 4     155
# Name: Journey_Day, dtype: int64
# _____________________
# 6     650
# 3     545
# 5     489
# 9     363
# 1     274
# 12    257
# 4      93
# Name: Journey_Month, dtype: int64
# _____________________
# 2     565
# 1     164
# 5     127
# 3     126
# 7     113
# 12    110
# 13    109
# 8     107
# 9     106
# 10    104
# 11    102
# 6     102
# 14     87
# 15     71
# 23     66
# 4      56
# 22     55
# 16     52
# 26     51
# 25     45
# 24     43
# 27     43
# 20     41
# 21     41
# 18     38
# 19     34
# 17     32
# 28     22
# 30     12
# 29     11
# 33      8
# 38      7
# 37      5
# 36      4
# 35      3
# 32      3
# 31      2
# 39      1
# 34      1
# 40      1
# 0       1
# Name: Duration_hours, dtype: int64
# _____________________
# 30    372
# 20    263
# 45    258
# 0     253
# 50    233
# 15    232
# 55    211
# 35    210
# 25    206
# 40    166
# 5     145
# 10    122
# Name: Duration_mins, dtype: int64
# _____________________
# 9     236
# 7     200
# 6     176
# 20    175
# 8     175
# 17    152
# 5     147
# 19    143
# 10    141
# 11    134
# 21    133
# 16    132
# 14    124
# 15    112
# 18    109
# 22     99
# 13     94
# 12     54
# 4      49
# 2      34
# 23     28
# 0      11
# 1       7
# 3       6
# Name: Dep_Hour, dtype: int64
# _____________________
# 0     528
# 30    276
# 55    274
# 45    230
# 10    209
# 15    184
# 5     178
# 50    176
# 25    173
# 20    153
# 35    148
# 40    142
# Name: Dep_Min, dtype: int64
# _____________________
# 19    431
# 12    198
# 21    195
# 22    190
# 4     175
# 1     159
# 18    126
# 23    123
# 8     123
# 10    117
# 20    112
# 7     101
# 9     101
# 0      89
# 16     79
# 11     67
# 14     65
# 13     64
# 17     51
# 15     40
# 5      26
# 3      14
# 2      13
# 6      12
# Name: Arrival_Hour, dtype: int64
# _____________________
# 0     381
# 15    326
# 25    297
# 35    254
# 30    230
# 20    204
# 45    192
# 50    185
# 5     179
# 40    156
# 10    140
# 55    127
# Name: Arrival_Min, dtype: int64
# _____________________

# %% [markdown]
# From the above value counts we can observe some repeated categories in some columns. Let's replace them.

# %%
# Replacing "Jet Airways Business" as "Jet Airways" in the column Airline
test_df["Airline"] = test_df["Airline"].replace("Jet Airways Business","Jet Airways")

# Replacing "Multiple carriers Premium economy" as "Multiple carriers" in Airline column
test_df["Airline"] = test_df["Airline"].replace("Multiple carriers Premium economy","Multiple carriers")

# Replacing "Vistara Premium economy" as "Vistara" in Airline column
test_df["Airline"] = test_df["Airline"].replace("Vistara Premium economy","Vistara")

# Replacing "New Delhi" as "Delhi" in Destination column
test_df["Destination"] = test_df["Destination"].replace("New Delhi","Delhi")

# In the column Additional Info, "No Info" and "No info" are one and the same so replace it by "No Info" 
test_df["Additional_Info"] = test_df["Additional_Info"].replace("No info","No Info")

# Replacing "1 Long layover" and "2 Long layover" as "Long layover"in the column Additional Info
test_df["Additional_Info"] = test_df["Additional_Info"].replace(["1 Long layover","2 Long layover"],"Long layover")

# %%
val_count = ["Airline","Destination", "Additional_Info"]

for i in val_count:
    print(test_df[i].value_counts())
    print("_______________________________")
# Out:
# Jet Airways          899
# IndiGo               511
# Air India            440
# Multiple carriers    350
# SpiceJet             208
# Vistara              131
# Air Asia              86
# GoAir                 46
# Name: Airline, dtype: int64
# _______________________________
# Cochin       1145
# Banglore      710
# Delhi         555
# Hyderabad     186
# Kolkata        75
# Name: Destination, dtype: int64
# _______________________________
# No Info                         2148
# In-flight meal not included      444
# No check-in baggage included      76
# Long layover                       1
# Business class                     1
# Change airports                    1
# Name: Additional_Info, dtype: int64
# _______________________________

# %%
# Checking number of unique values in each column
test_df.nunique()
# Out:
# Airline              8
# Source               5
# Destination          5
# Route              100
# Total_Stops          5
# Additional_Info      6
# Journey_Day          9
# Journey_Month        7
# Duration_hours      41
# Duration_mins       12
# Dep_Hour            24
# Dep_Min             12
# Arrival_Hour        24
# Arrival_Min         12
# dtype: int64

# %% [markdown]
# These are the number of unique values present in each columns.

# %%
# Checking null values in the dataframe
test_df.isnull().sum()
# Out:
# Airline            0
# Source             0
# Destination        0
# Route              0
# Total_Stops        0
# Additional_Info    0
# Journey_Day        0
# Journey_Month      0
# Duration_hours     0
# Duration_mins      0
# Dep_Hour           0
# Dep_Min            0
# Arrival_Hour       0
# Arrival_Min        0
# dtype: int64

# %% [markdown]
# There are no missing values present in any of the columns.

# %% [markdown]
# ## Statistical Summary of the Test Data

# %%
test_df.describe()
# Out:
#        Journey_Day  Journey_Month  Duration_hours  Duration_mins     Dep_Hour  \
# count  2671.000000    2671.000000     2671.000000    2671.000000  2671.000000
# mean     12.026956       5.607263       10.189068      28.397604    12.603519
# std       8.564408       3.042952        8.390683      16.747651     5.686673
# min       3.000000       1.000000        0.000000       0.000000     0.000000
# 25%       5.000000       3.000000        2.000000      15.000000     8.000000
# 50%       6.000000       5.000000        8.000000      30.000000    12.000000
# 75%      21.000000       6.000000       15.000000      45.000000    18.000000
# max      27.000000      12.000000       40.000000      55.000000    23.000000
#
#            Dep_Min  Arrival_Hour  Arrival_Min
# count  2671.000000   2671.000000  2671.000000
# mean     24.891426     13.585174    24.558218
# std      19.086522      7.040396    16.775436
# min       0.000000      0.000000     0.000000
# 25%       5.000000      8.000000    10.000000
# 50%      25.000000     15.000000    25.000000
# 75%      45.000000     19.000000    35.000000
# max      55.000000     23.000000    55.000000

# %% [markdown]
# This gives the statistical information of the dataset. The summary of this dataset looks perfect since there is no negative/ invalid values present. It gives the summary of numerical data.

# %%
# checking for categorical columns
categorical_col=[]
for i in test_df.dtypes.index:
    if test_df.dtypes[i]=='object':
        categorical_col.append(i)
print(categorical_col)
# Out:
# ['Airline', 'Source', 'Destination', 'Route', 'Total_Stops', 'Additional_Info']

# %%
# Now checking for numerical columns
numerical_col=[]
for i in test_df.dtypes.index:
    if test_df.dtypes[i]!='object':
        numerical_col.append(i)
print(numerical_col)
# Out:
# ['Journey_Day', 'Journey_Month', 'Duration_hours', 'Duration_mins', 'Dep_Hour', 'Dep_Min', 'Arrival_Hour', 'Arrival_Min']

# %% [markdown]
# ## Identifying the outliers

# %%
plt.figure(figsize=(15,15),facecolor='white')
plotnumber=1
for column in numerical_col:
    if plotnumber<=9:
        ax=plt.subplot(3,3,plotnumber)
        sns.boxplot(test_df[column],color="darkorange")
        plt.xlabel(column,fontsize=15)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# ## Removing outliers

# %%
feature = test_df[['Duration_hours','Journey_Month']]

z=np.abs(zscore(feature))

z
# Out:
#       Duration_hours  Journey_Month
# 0           0.022537       0.129089
# 1           0.737750       2.101227
# 2           1.527090       0.199601
# 3           0.335069       0.199601
# 4           0.976154       0.129089
# ...              ...            ...
# 2666        1.527090       0.129089
# 2667        0.976154       0.856981
# 2668        0.499346       0.129089
# 2669        0.573473       0.129089
# 2670        0.454271       0.129089
#
# [2671 rows x 2 columns]

# %%
# Creating new dataframe
new_test_df = test_df[(z<3).all(axis=1)] 
new_test_df
# Out:
#                 Airline    Source Destination            Route Total_Stops  \
# 0           Jet Airways     Delhi      Cochin  DEL → BOM → COK      1 stop
# 1                IndiGo   Kolkata    Banglore  CCU → MAA → BLR      1 stop
# 2           Jet Airways     Delhi      Cochin  DEL → BOM → COK      1 stop
# 3     Multiple carriers     Delhi      Cochin  DEL → BOM → COK      1 stop
# 4              Air Asia  Banglore       Delhi        BLR → DEL    non-stop
# ...                 ...       ...         ...              ...         ...
# 2666          Air India   Kolkata    Banglore  CCU → DEL → BLR      1 stop
# 2667             IndiGo   Kolkata    Banglore        CCU → BLR    non-stop
# 2668        Jet Airways     Delhi      Cochin  DEL → BOM → COK      1 stop
# 2669          Air India     Delhi      Cochin  DEL → BOM → COK      1 stop
# 2670  Multiple carriers     Delhi      Cochin  DEL → BOM → COK      1 stop
#
#                   Additional_Info  Journey_Day  Journey_Month  Duration_hours  \
# 0                         No Info            6              6              10
# 1                         No Info            5             12               4
# 2     In-flight meal not included           21              5              23
# 3                         No Info           21              5              13
# 4                         No Info           24              6               2
# ...                           ...          ...            ...             ...
# 2666                      No Info            6              6              23
# 2667                      No Info           27              3               2
# 2668                      No Info            3              6               6
# 2669                      No Info            3              6              15
# 2670                      No Info           15              6              14
#
#       Duration_mins  Dep_Hour  Dep_Min  Arrival_Hour  Arrival_Min
# 0                55        17       30             4           25
# 1                 0         6       20            10           20
# 2                45        19       15            19            0
# 3                 0         8        0            21            0
# 4                50        23       55             2           45
# ...             ...       ...      ...           ...          ...
# 2666             55        20       30            20           25
# 2667             35        14       20            16           55
# 2668             35        21       50             4           25
# 2669             15         4        0            19           15
# 2670             20         4       55            19           15
#
# [2653 rows x 14 columns]

# %% [markdown]
# ## Checking skewness in the data

# %%
new_test_df.skew().sort_values()
# Out:
# Arrival_Hour     -0.432551
# Duration_mins    -0.110629
# Dep_Hour          0.083357
# Arrival_Min       0.110111
# Dep_Min           0.132681
# Journey_Day       0.475210
# Journey_Month     0.591565
# Duration_hours    0.795392
# dtype: float64

# %% [markdown]
# ## Removing skewness using log transformation

# %%
new_test_df["Duration_hours"] = np.log1p(new_test_df["Duration_hours"])
new_test_df["Journey_Month"] = np.log1p(new_test_df["Journey_Month"])

# %%
new_test_df.skew().sort_values()
# Out:
# Journey_Month    -0.541053
# Arrival_Hour     -0.432551
# Duration_hours   -0.134743
# Duration_mins    -0.110629
# Dep_Hour          0.083357
# Arrival_Min       0.110111
# Dep_Min           0.132681
# Journey_Day       0.475210
# dtype: float64

# %% [markdown]
# ## Encoding the Categorical columns

# %%
le=LabelEncoder()
new_test_df[categorical_col]= new_test_df[categorical_col].apply(le.fit_transform)
new_test_df
# Out:
#       Airline  Source  Destination  Route  Total_Stops  Additional_Info  \
# 0           4       2            1     76            0                4
# 1           3       3            0     65            0                4
# 2           4       2            1     76            0                2
# 3           5       2            1     76            0                4
# 4           0       0            2     16            4                4
# ...       ...     ...          ...    ...          ...              ...
# 2666        1       3            0     51            0                4
# 2667        3       3            0     43            4                4
# 2668        4       2            1     76            0                4
# 2669        1       2            1     76            0                4
# 2670        5       2            1     76            0                4
#
#       Journey_Day  Journey_Month  Duration_hours  Duration_mins  Dep_Hour  \
# 0               6       1.945910        2.397895             55        17
# 1               5       2.564949        1.609438              0         6
# 2              21       1.791759        3.178054             45        19
# 3              21       1.791759        2.639057              0         8
# 4              24       1.945910        1.098612             50        23
# ...           ...            ...             ...            ...       ...
# 2666            6       1.945910        3.178054             55        20
# 2667           27       1.386294        1.098612             35        14
# 2668            3       1.945910        1.945910             35        21
# 2669            3       1.945910        2.772589             15         4
# 2670           15       1.945910        2.708050             20         4
#
#       Dep_Min  Arrival_Hour  Arrival_Min
# 0          30             4           25
# 1          20            10           20
# 2          15            19            0
# 3           0            21            0
# 4          55             2           45
# ...       ...           ...          ...
# 2666       30            20           25
# 2667       20            16           55
# 2668       50             4           25
# 2669        0            19           15
# 2670       55            19           15
#
# [2653 rows x 14 columns]

# %% [markdown]
# ## Feature Scaling using Standard Scalarization

# %%
scaler = StandardScaler()
new_test_df = pd.DataFrame(scaler.fit_transform(new_test_df), columns=new_test_df.columns)
new_test_df
# Out:
#        Airline    Source  Destination     Route  Total_Stops  Additional_Info  \
# 0     0.233214  0.031440    -0.167242  0.804966    -0.791072         0.393727
# 1    -0.348833  0.873978    -1.175634  0.398570    -0.791072         0.393727
# 2     0.233214  0.031440    -0.167242  0.804966    -0.791072        -2.166466
# 3     0.815260  0.031440    -0.167242  0.804966    -0.791072         0.393727
# 4    -2.094973 -1.653635     0.841150 -1.411740     1.429790         0.393727
# ...        ...       ...          ...       ...          ...              ...
# 2648 -1.512927  0.873978    -1.175634 -0.118662    -0.791072         0.393727
# 2649 -0.348833  0.873978    -1.175634 -0.414222     1.429790         0.393727
# 2650  0.233214  0.031440    -0.167242  0.804966    -0.791072         0.393727
# 2651 -1.512927  0.031440    -0.167242  0.804966    -0.791072         0.393727
# 2652  0.815260  0.031440    -0.167242  0.804966    -0.791072         0.393727
#
#       Journey_Day  Journey_Month  Duration_hours  Duration_mins  Dep_Hour  \
# 0       -0.706193       0.344970        0.374141       1.583185  0.766320
# 1       -0.823069       1.565339       -0.579376      -1.697747 -1.172433
# 2        1.046954       0.041078        1.317622       0.986652  1.118821
# 3        1.046954       0.041078        0.665790      -1.697747 -0.819933
# 4        1.397583       0.344970       -1.197140       1.284918  1.823822
# ...           ...            ...             ...            ...       ...
# 2648    -0.706193       0.344970        1.317622       1.583185  1.295071
# 2649     1.748212      -0.758252       -1.197140       0.390119  0.237569
# 2650    -1.056822       0.344970       -0.172465       0.390119  1.471321
# 2651    -1.056822       0.344970        0.827275      -0.802948 -1.524934
# 2652     0.345695       0.344970        0.749226      -0.504681 -1.524934
#
#        Dep_Min  Arrival_Hour  Arrival_Min
# 0     0.272445     -1.354818     0.025591
# 1    -0.252462     -0.503215    -0.272182
# 2    -0.514916      0.774190    -1.463273
# 3    -1.302277      1.058057    -1.463273
# 4     1.584714     -1.638686     1.216682
# ...        ...           ...          ...
# 2648  0.272445      0.916123     0.025591
# 2649 -0.252462      0.348388     1.812227
# 2650  1.322260     -1.354818     0.025591
# 2651 -1.302277      0.774190    -0.569955
# 2652  1.584714      0.774190    -0.569955
#
# [2653 rows x 14 columns]

# %% [markdown]
# We have scaled the data using standard scalarizaion method to overcome with the issue of data biasness.
#
# We have already loaded the saved model after saving the final model. Now let's predict the flight price using test data.

# %% [markdown]
# # Prediction Results

# %%
# Predicting the flight price from the features of the testing data 
Predicted_Price = final_model.predict(new_test_df)
Predicted_Price
# Out:
# array([14561.23,  4588.57, 12978.14, ..., 13458.99, 10893.54,  7833.81])

# %% [markdown]
# # DataFrame and Saving the predictions

# %%
Prediction = pd.DataFrame()
Prediction['Price']= Predicted_Price
Prediction
# Out:
#          Price
# 0     14561.23
# 1      4588.57
# 2     12978.14
# 3     12271.09
# 4      3906.45
# ...        ...
# 2648   9671.41
# 2649   5030.37
# 2650  13458.99
# 2651  10893.54
# 2652   7833.81
#
# [2653 rows x 1 columns]

# %% [markdown]
# Here we are adding the predicted price output to our original test dataset to complete it with features and target column.

# %%
## Saving the predictions
Prediction.to_csv("Flight_Price_Test_Data_Predicted_Values.csv", index=False)

# %% [markdown]
# With the help of .to_csv we have exported the entire dataset in comma separated values format that can be checked using the Excel spreadsheet program.

# %% [markdown]
# ## Modelling the Training Dataset and Prediction of the Flight Prices using the Testing Dataset is completed.
